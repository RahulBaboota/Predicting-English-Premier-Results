# %%
## Importing necessary libraries and modules.
import warnings
import numpy as np
import pandas as pd
from pprint import pprint
from InputData import loadDataFrameList

warnings.filterwarnings('ignore')

# %%
DataFrame = pd.read_csv('./EngineeredData.csv')
pprint(list(DataFrame.columns.unique()))
# Out:
# ['AAttack',
#  'AC',
#  'ACKPP',
#  'ADefense',
#  'AF',
#  'AForm',
#  'AGKPP',
#  'AMidfield',
#  'AOverall',
#  'AR',
#  'AS',
#  'AST',
#  'ASTKPP',
#  'ASt',
#  'AStWeighted',
#  'ATGD',
#  'AY',
#  'Attack',
#  'AwayTeam',
#  'B365A',
#  'B365D',
#  'B365H',
#  'BSA',
#  'BSD',
#  'BSH',
#  'BWA',
#  'BWD',
#  'BWH',
#  'Bb1X2',
#  'BbAH',
#  'BbAHh',
#  'BbAv<2.5',
#  'BbAv>2.5',
#  'BbAvA',
#  'BbAvAHA',
#  'BbAvAHH',
#  'BbAvD',
#  'BbAvH',
#  'BbMx<2.5',
#  'BbMx>2.5',
#  'BbMxA',
#  'BbMxAHA',
#  'BbMxAHH',
#  'BbMxD',
#  'BbMxH',
#  'BbOU',
#  'CKPP',
#  'Date',
#  'Defense',
#  'Div',
#  'FTAG',
#  'FTHG',
#  'FTR',
#  'Form',
#  'GBA',
#  'GBD',
#  'GBH',
#  'GD',
#  'GKPP',
#  'HAttack',
#  'HC',
#  'HCKPP',
#  'HDefense',
#  'HF',
#  'HForm',
#  'HGKPP',
#  'HMidfield',
#  'HOverall',
#  'HR',
#  'HS',
#  'HST',
#  'HSTKPP',
#  'HSt',
#  'HStWeighted',
#  'HTAG',
#  'HTGD',
#  'HTHG',
#  'HTR',
#  'HY',
#  'HomeTeam',
#  'IWA',
#  'IWD',
#  'IWH',
#  'LBA',
#  'LBD',
#  'LBH',
#  'MATGD',
#  'MHTGD',
#  'Midfield',
#  'Overall',
#  'PSA',
#  'PSCA',
#  'PSCD',
#  'PSCH',
#  'PSD',
#  'PSH',
#  'Referee',
#  'SBA',
#  'SBD',
#  'SBH',
#  'SJA',
#  'SJD',
#  'SJH',
#  'STKPP',
#  'Season',
#  'Streak',
#  'VCA',
#  'VCD',
#  'VCH',
#  'WHA',
#  'WHD',
#  'WHH',
#  'WeightedStreak']

# %%
DataFrame.describe()
# Out:
#            AAttack           AC        ACKPP     ADefense           AF  \
# count  4940.000000  4940.000000  4159.000000  4940.000000  4940.000000
# mean     78.315385     4.804049     5.521920    75.915385    11.640891
# std       4.606540     2.746432     1.423806     3.950151     3.778621
# min      68.000000     0.000000     1.500000    65.000000     1.000000
# 25%      75.000000     3.000000     4.500000    73.000000     9.000000
# 50%      78.000000     4.000000     5.333333    75.000000    11.000000
# 75%      82.000000     6.000000     6.333333    79.000000    14.000000
# max      92.000000    19.000000    11.333333    86.000000    26.000000
#
#              AForm        AGKPP    AMidfield     AOverall           AR  \
# count  4940.000000  4159.000000  4940.000000  4940.000000  4940.000000
# mean      1.035386     1.351687    76.842308    76.853846     0.091903
# std       0.720516     0.603662     4.159995     3.679025     0.299921
# min       0.012755     0.000000    66.000000    68.000000     0.000000
# 25%       0.534749     0.833333    74.000000    74.000000     0.000000
# 50%       0.898900     1.333333    76.000000    76.000000     0.000000
# 75%       1.330000     1.666667    80.000000    80.000000     0.000000
# max       6.435924     4.500000    88.000000    87.000000     2.000000
#
#             ...                SJH        STKPP       Streak          VCA  \
# count       ...        3459.000000  4151.000000  4151.000000  4940.000000
# mean        ...           2.611411    -0.103108    -0.016194     4.933459
# std         ...           1.640732     2.296151     0.298742     4.033390
# min         ...           1.100000   -10.833333    -1.000000     1.150000
# 25%         ...           1.645000    -1.500000    -0.222222     2.500000
# 50%         ...           2.100000     0.000000     0.000000     3.500000
# 75%         ...           2.750000     1.333333     0.166667     5.500000
# max         ...          15.000000     9.166667     0.944444    31.000000
#
#                VCD          VCH          WHA          WHD          WHH  \
# count  4940.000000  4940.000000  4833.000000  4833.000000  4833.000000
# mean      3.944943     2.744559     4.653718     3.680002     2.680412
# std       1.069156     1.838800     3.665501     0.878646     1.705640
# min       2.500000     1.060000     1.140000     2.800000     1.070000
# 25%       3.300000     1.670000     2.500000     3.200000     1.670000
# 50%       3.500000     2.150000     3.400000     3.300000     2.150000
# 75%       4.000000     2.900000     5.250000     3.800000     2.800000
# max      13.000000    19.000000    26.000000    11.000000    17.000000
#
#        WeightedStreak
# count     4151.000000
# mean        -0.027995
# std          0.318051
# min         -1.000000
# 25%         -0.253968
# 50%         -0.031746
# 75%          0.190476
# max          0.920635
#
# [8 rows x 105 columns]

# %% [markdown]
# <h1><center> Removing Unwanted Fields </center></h1>

# %%
## Creating a list of betting odds column fields.
bettingStats = ["B365H","B365D","B365A","BWH","BWD","BWA","GBH","GBD","GBA","IWH","IWD","IWA","LBH","LBD","LBA","SBH","SBD","SBA","WHH","WHD","WHA","SJH","SJD","SJA","VCH","VCD","VCA","Bb1X2","BbMxH","BbAvH","BbMxD","BbAvD","BbMxA","BbAvA","BbOU","BbMx>2.5","BbAv>2.5","BbMx<2.5","BbAv<2.5","BbAH","BbAHh","BbMxAHH","BbAvAHH","BbMxAHA","BbAvAHA"]
bettingStatsEx = ["BSH", "BSD", "BSA", "PSA", "PSH", "PSD", "PSCA", "PSCD", "PSCH"]

## Creating a list of general unnecesaary column fields.
genDropInfo = ["Div", "Date", "HomeTeam", "AwayTeam", "Referee"]

## Creating a list of unnecessary pre-existing feature columns.
preDropFeatures = ["FTHG", "FTAG", "HTHG", "HTAG", "HS", "AS", "HST", "AST", "HTR", "HS", "AS", "HF", "AF", "HY", "AY", "HR", "AR", "HC", "AC", "MHTGD", "MATGD"]

## Dropping the above coloumns .
DataFrame.drop(bettingStats + bettingStatsEx + genDropInfo + preDropFeatures, axis = 1, inplace = True)

pprint(list(DataFrame.columns.unique()))
# Out:
# ['AAttack',
#  'ACKPP',
#  'ADefense',
#  'AForm',
#  'AGKPP',
#  'AMidfield',
#  'AOverall',
#  'ASTKPP',
#  'ASt',
#  'AStWeighted',
#  'ATGD',
#  'Attack',
#  'CKPP',
#  'Defense',
#  'FTR',
#  'Form',
#  'GD',
#  'GKPP',
#  'HAttack',
#  'HCKPP',
#  'HDefense',
#  'HForm',
#  'HGKPP',
#  'HMidfield',
#  'HOverall',
#  'HSTKPP',
#  'HSt',
#  'HStWeighted',
#  'HTGD',
#  'Midfield',
#  'Overall',
#  'STKPP',
#  'Season',
#  'Streak',
#  'WeightedStreak']

# %%
## List of features who's initial values are Nan.
nanFeatures = ['GKPP', 'HGKPP', 'AGKPP', 'CKPP', 'HCKPP', 'ACKPP', 'STKPP', 'HSTKPP', 'ASTKPP', 'Streak', 'HSt', 'ASt', 'WeightedStreak', 'HStWeighted', 'AStWeighted']

## Getting a list of the unique seasons.
seasonNames = list(DataFrame.Season.unique())
dataFramesList = []

for season in seasonNames:
    
    ## Creating a Temporary DataFrame season-wise.
    tempDF = DataFrame[ (DataFrame['Season'] == (season) )]
    tempDF = tempDF.dropna(subset = nanFeatures)
    dataFramesList.append(tempDF)

DataFrame = pd.concat(dataFramesList)  
print DataFrame.isnull().values.sum()
# Out:
# 11745
# 0

# %% [markdown]
# <h1><center> Splitting Data into Training and Testing Splits </center></h1>

# %%
## For our "Target Variable" , we need the match outcomes which is the field "FTR" (Full Time Result) .
## So , we will create a slice of this coloumn as well as "Season" (for indexing purposes) .
Y = DataFrame[['FTR','Season']]

## Now , we will choose the first 11 seasons as our Training Set and the final 2 as Testing Set .
YTrain = Y[ (Y['Season'] == '2005-2006') | (Y['Season'] == '2006-2007') | (Y['Season'] == '2007-2008') | (Y['Season'] == '2008-2009') | (Y['Season'] == '2009-2010') | (Y['Season'] == '2010-2011') | (Y['Season'] == '2011-2012') | (Y['Season'] == '2012-2013') | (Y['Season'] == '2013-2014') | (Y['Season'] == '2014-2015') | (Y['Season'] == '2015-2016')]         
YTest = Y[ (Y['Season'] == '2016-2017') | (Y['Season'] == '2017-2018')]

## Now , we dont need the "Season" coloumn so drop it .
YTrain.drop(['Season'], axis = 1, inplace = True)
YTest.drop(['Season'], axis = 1, inplace = True)

# %%
## Now, for creating the feature set, we first need to remove the target variable from the DataFrame .
X = DataFrame
X.drop(['FTR'], axis = 1, inplace = True)

## Now , we will choose the first 11 seasons as our Training Set and the final 2 as Testing Set .
XTrain = X[ (X['Season'] == '2005-2006') | (X['Season'] == '2006-2007') | (X['Season'] == '2007-2008') | (X['Season'] == '2008-2009') | (X['Season'] == '2009-2010') | (X['Season'] == '2010-2011') | (X['Season'] == '2011-2012') | (X['Season'] == '2012-2013') | (X['Season'] == '2013-2014') | (X['Season'] == '2014-2015') | (X['Season'] == '2015-2016')] 
XTest = X[ (X['Season'] == '2016-2017') | (X['Season'] == '2017-2018')]

## Now , we dont need the "Season" coloumn so drop it .
XTrain.drop(['Season'], axis = 1, inplace = True)
XTest.drop(['Season'], axis = 1, inplace = True)f

pprint(list(XTest.columns.unique()))
# Out:
# ['AAttack',
#  'ACKPP',
#  'ADefense',
#  'AForm',
#  'AGKPP',
#  'AMidfield',
#  'AOverall',
#  'ASTKPP',
#  'ASt',
#  'AStWeighted',
#  'ATGD',
#  'Attack',
#  'CKPP',
#  'Defense',
#  'Form',
#  'GD',
#  'GKPP',
#  'HAttack',
#  'HCKPP',
#  'HDefense',
#  'HForm',
#  'HGKPP',
#  'HMidfield',
#  'HOverall',
#  'HSTKPP',
#  'HSt',
#  'HStWeighted',
#  'HTGD',
#  'Midfield',
#  'Overall',
#  'STKPP',
#  'Streak',
#  'WeightedStreak']

# %% [markdown]
# <h1><center> Splitting the feature set into Set A and Set B </center></h1>

# %%
## The set of features to be added in Set A i.e. the non-differential features.
nonDifferentialFeatures = ["ATGD", "HTGD", "ACKPP", "HCKPP", "AGKPP", "HGKPP", "ASTKPP", "HSTKPP", "ASt", "HSt", "AStWeighted", "HStWeighted", "AForm", "HForm", "AOverall", "HOverall", "AAttack", "HAttack", "AMidfield", "HMidfield", "ADefense", "HDefense"]

## Choosing the above feature set.
XTrainA = XTrain[nonDifferentialFeatures]
XTestA = XTest[nonDifferentialFeatures]

# %%
## The set of features to be added in Set B i.e. the differential features.
differentialFeatures = ["GD", "CKPP", "GKPP", "STKPP", "Streak", "WeightedStreak", "Form", "Overall", "Attack", "Midfield", "Defense"]

## Choosing the above feature set.
XTrainB = XTrain[differentialFeatures]
XTestB = XTest[differentialFeatures]

pprint(list(XTestB.columns.unique()))
# Out:
# ['GD',
#  'CKPP',
#  'GKPP',
#  'STKPP',
#  'Streak',
#  'WeightedStreak',
#  'Form',
#  'Overall',
#  'Attack',
#  'Midfield',
#  'Defense']
